# %%
import numpy as np
weights = np.zeros((11591, 2))
wt_file = open('features.category')

# %%
i = 0
for line in wt_file.readlines():
    line = line.strip().split(' ')
    j = 0
    for word in line:
        weights[i][j] = word
        j += 1
    i += 1
weights.shape
# Out:
# (11591, 2)

# %%
# sanity check
print(weights[0])
print(weights[900])
print(type(weights[0][1]))
# Out:
# [0.1019661  0.09509591]
# [0.10196421 0.09509571]
# <class 'numpy.float64'>

# %%
# kmeans clustering on weights
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters = 6, random_state = 0, init = 'k-means++', max_iter = 500, n_init = 1).fit(weights)
labels = kmeans.labels_
print(len(labels))
# Out:
# 11591

# %%
import pandas as pd
data = pd.read_csv('category.csv')
text, label = [], []
for i in data.index:
    text.append(data['DESCRIPTION'][i])
    label.append(data['CATEGORY'][i])

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from collections import defaultdict
label_ids = [0, 1, 2, 3, 4, 5] # 6 labels
text_j = [] 
labels_dict = [] 
for i in range(6):
    dict_ = defaultdict(int)
    text_ = []
    labels_dict.append(dict_)
    text_j.append(text_)
    
for i in range(len(labels)):
    for j in label_ids:
        if labels[i] == j:
            text_j[j].append(text[i])
            labels_dict[j][label[i]] += 1

# %%
cluster_cen = kmeans.cluster_centers_
cluster_cen
# Out:
# array([[0.10196559, 0.09509883],
#        [0.10196464, 0.09509125],
#        [0.1019605 , 0.09509769],
#        [0.10196382, 0.0950952 ],
#        [0.10196811, 0.09509475],
#        [0.10196035, 0.09509311]])

# %%
# based on max values in labels_dict
cluster_labels = ['Commenting', 'Touching/Groping', 'Rape/Sexual Assault', 'Catcalls/Whistles', 'Others', 
               'Ogling/Facial Expressions/Staring']

# %%
import matplotlib.pyplot as plt

colors = ["lightcoral", "lightskyblue", "tab:pink", "aquamarine", "lightpink", "mistyrose"]
x_axis = [o[0] for o in weights]
y_axis = [o[1] for o in weights]

fig, ax = plt.subplots(figsize=(20,10))
ax.set_xbound(lower = 0.000050, upper = 0.000075)
ax.set_ybound(lower = 0.09508, upper = 0.09511)

ax.scatter(x_axis, y_axis, c = [colors[d] for d in labels])

for i, x in enumerate(cluster_labels):
    ax.annotate(x, (cluster_cen[i][0], cluster_cen[i][1]), fontsize = 15)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
# top features for each cluster

for i in range(6):
    print("Top features for cluster ", i, " --- ", cluster_labels[i])
    vectorizer = TfidfVectorizer(max_features = 15, stop_words = 'english')  
    feat = vectorizer.fit_transform(text_j[i])
    print(vectorizer.get_feature_names())
    print()
# Out:
# Top features for cluster  0  ---  Commenting
# ['away', 'boys', 'college', 'commenting', 'evening', 'friend', 'girl', 'girls', 'group', 'guys', 'man', 'men', 'quot', 'started', 'station']
#
# Top features for cluster  1  ---  Touching/Groping
# ['boy', 'boys', 'bus', 'evening', 'friend', 'girl', 'going', 'guy', 'happened', 'harassment', 'home', 'man', 'time', 'touching', 'walking']
#
# Top features for cluster  2  ---  Rape/Sexual Assault
# ['boys', 'commenting', 'friend', 'girl', 'girls', 'guy', 'guys', 'home', 'house', 'man', 'school', 'started', 'street', 'touch', 'tried']
#
# Top features for cluster  3  ---  Catcalls/Whistles
# ['boy', 'boys', 'bus', 'commenting', 'comments', 'evening', 'friend', 'girl', 'girls', 'guy', 'guys', 'home', 'man', 'started', 'walking']
#
# Top features for cluster  4  ---  Others
# ['afternoon', 'boys', 'bus', 'came', 'commenting', 'evening', 'friend', 'girl', 'group', 'man', 'men', 'passing', 'started', 'station', 'walking']
#
# Top features for cluster  5  ---  Ogling/Facial Expressions/Staring
# ['boy', 'boys', 'bus', 'friend', 'girl', 'going', 'guy', 'happened', 'home', 'man', 'market', 'street', 'touch', 'tried', 'way']
